# %% [markdown]
# <a href="https://colab.research.google.com/github/bala-ceg/Quix_Example/blob/main/ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
url = "https://disease.sh/v3/covid-19/historical/all?lastdays=all"
source = requests.get(url).json()
df = pd.DataFrame.from_records(source)
df.reset_index(level = 0, inplace = True)

# %%
df
# Out:
#         index      cases   deaths  recovered
# 0     1/22/20        557       17         30
# 1     1/23/20        657       18         32
# 2     1/24/20        944       26         39
# 3     1/25/20       1437       42         42
# 4     1/26/20       2120       56         56
# ..        ...        ...      ...        ...
# 995  10/13/22  623806782  6564825          0
# 996  10/14/22  624259477  6566368          0
# 997  10/15/22  624475375  6567029          0
# 998  10/16/22  624666814  6567444          0
# 999  10/17/22  625201215  6569150          0
#
# [1000 rows x 4 columns]

# %%
headers = list(df)
for index, row in df.iterrows():

    data_frame_row = pd.DataFrame()

    for header in headers:
        value = row[header]
        data_frame_row[header] = [value]
    print(data_frame_row)
# Out:
#      index  cases  deaths  recovered
# 0  1/22/20    557      17         30
#      index  cases  deaths  recovered
# 0  1/23/20    657      18         32
#      index  cases  deaths  recovered
# 0  1/24/20    944      26         39
#      index  cases  deaths  recovered
# 0  1/25/20   1437      42         42
#      index  cases  deaths  recovered
# 0  1/26/20   2120      56         56
#      index  cases  deaths  recovered
# 0  1/27/20   2929      82         65
#      index  cases  deaths  recovered
# 0  1/28/20   5580     131        108
#      index  cases  deaths  recovered
# 0  1/29/20   6169     133        127
#      index  cases  deaths  recovered
# 0  1/30/20   8237     172        145
#      index  cases  deaths  recovered
# 0  1/31/20   9927     214        225
#     index  cases  deaths  recovered
# 0  2/1/20  12038     260        287
#     index  cases  deaths  recovered
# 0  2/2/20  16787     364        476
#     index  cases  deaths  recovered
# ...

# %%
df_min_max_scaled = df.copy()
column ='cases'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
column ='deaths'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
column ='recovered'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())

# %%
df_min_max_scaled
# Out:
#         index         cases        deaths     recovered
# 0     1/22/20  0.000000e+00  0.000000e+00  2.368237e-07
# 1     1/23/20  1.599486e-07  1.522271e-07  2.521026e-07
# 2     1/24/20  6.190013e-07  1.370044e-06  3.055790e-07
# 3     1/25/20  1.407548e-06  3.805677e-06  3.284974e-07
# 4     1/26/20  2.499997e-06  5.936857e-06  4.354500e-07
# ..        ...           ...           ...           ...
# 995  10/13/22  9.977696e-01  9.993416e-01  7.639474e-09
# 996  10/14/22  9.984937e-01  9.995765e-01  7.639474e-09
# 997  10/15/22  9.988390e-01  9.996771e-01  7.639474e-09
# 998  10/16/22  9.991452e-01  9.997403e-01  7.639474e-09
# 999  10/17/22  1.000000e+00  1.000000e+00  7.639474e-09
#
# [1000 rows x 4 columns]

# %%
df_test = df_min_max_scaled.loc[df_min_max_scaled['deaths'] > 0.5]

# %%
df_test
# Out:
#         index     cases    deaths     recovered
# 463   4/29/21  0.241529  0.502229  6.688387e-01
# 464   4/30/21  0.242955  0.504425  6.740839e-01
# 465    5/1/21  0.244226  0.506410  6.792975e-01
# 466    5/2/21  0.245325  0.507982  6.845917e-01
# 467    5/3/21  0.246430  0.509761  6.895076e-01
# ..        ...       ...       ...           ...
# 995  10/13/22  0.997770  0.999342  7.639474e-09
# 996  10/14/22  0.998494  0.999577  7.639474e-09
# 997  10/15/22  0.998839  0.999677  7.639474e-09
# 998  10/16/22  0.999145  0.999740  7.639474e-09
# 999  10/17/22  1.000000  1.000000  7.639474e-09
#
# [537 rows x 4 columns]
